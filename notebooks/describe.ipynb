# %%
import sys
sys.path.append('../src')
from database import read_data_sql


query = """
SELECT *
FROM bike_sharing
ORDER BY date_time DESC"""

df = read_data_sql(query)

# %%
media = df.users.mean()
RMSE = 38.99
error = RMSE / media * 100
print(f'Media de {media}, RMSE {RMSE} y error de {error}%')
# Out:
# Media de 187.79508663930687, RMSE 38.99 y error de 20.761991539686594%
